# %%
import train_loop

# %%
style="Cubism"
image_size=256
batch_size=4
num_epochs=2
num_workers=4
style_mode="gram"
data_dir_base="/scratch/cmpe258-sp25/group3_styletransfer/"
save_every_n=None
train_loop.train_style_transfer(style=style,
                                image_size=image_size,
                                batch_size=batch_size,
                                num_epochs=num_epochs,
                                num_workers=num_workers,
                                style_mode=style_mode,
                                data_dir_base=data_dir_base,
                                save_every_n=save_every_n)
# Out:
# === Starting run: 2025-11-17 23:28:37 ===
# Device: cuda | Style: Cubism | Mode: gram
# Epoch [1/2], Step [0/30851], Content Loss: 3.0652, Style Loss: 0.0000, Total: 3.6289
# Saved new best model (loss: 3.6289)
# Saved new best model (loss: 3.5243)
# Saved new best model (loss: 2.7109)
# Saved new best model (loss: 2.0998)
# Saved new best model (loss: 1.8843)
# Saved new best model (loss: 1.6300)
# Saved new best model (loss: 1.6027)
# Saved new best model (loss: 1.5413)
# Saved new best model (loss: 1.2389)
# Epoch [1/2], Step [50/30851], Content Loss: 0.8170, Style Loss: 0.0000, Total: 2.6286
# Saved new best model (loss: 1.0489)
# Saved new best model (loss: 0.8175)
# Saved new best model (loss: 0.5815)
# Epoch [1/2], Step [100/30851], Content Loss: 0.3791, Style Loss: 0.0000, Total: 2.7789
# Epoch [1/2], Step [150/30851], Content Loss: 0.8564, Style Loss: 0.0000, Total: 4.1909
# Epoch [1/2], Step [200/30851], Content Loss: 4.3425, Style Loss: 0.0001, Total: 12.1360
# Epoch [1/2], Step [250/30851], Content Loss: 3.6795, Style Loss: 0.0000, Total: 4.5682
# Epoch [1/2], Step [300/30851], Content Loss: 4.9934, Style Loss: 0.0000, Total: 7.6361
# Epoch [1/2], Step [350/30851], Content Loss: 3.2970, Style Loss: 0.0000, Total: 4.0819
# Epoch [1/2], Step [400/30851], Content Loss: 4.2963, Style Loss: 0.0000, Total: 5.7059

# %%
exit()
